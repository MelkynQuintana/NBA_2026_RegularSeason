# %% [markdown]
# ### Data import and initial setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 


data = pd.read_csv('../nba_player_stats_2026.csv')

#Info in the dataset represents the whole season, we gonna calculate the mean statistic value per game played
temp = ['MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
       'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PTS']

for col in temp:
    data[col + '_pg'] = (data[col] / data['GP']).round(2)

# %% [markdown]
# ### Data Overview

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=3)

fig.add_trace(go.Histogram(x=data1, name='Hist 1'), row=1, col=1)
fig.add_trace(go.Histogram(x=data2, name='Hist 2'), row=1, col=2)
fig.add_trace(go.Histogram(x=data3, name='Hist 3'), row=1, col=3)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 import plotly.graph_objects as go
#       4 fig = make_subplots(rows=1, cols=3)
# ----> 6 fig.add_trace(go.Histogram(x=data1, name='Hist 1'), row=1, col=1)
#       7 fig.add_trace(go.Histogram(x=data2, name='Hist 2'), row=1, col=2)
#       8 fig.add_trace(go.Histogram(x=data3, name='Hist 3'), row=1, col=3)
#
# NameError: name 'data1' is not defined
